# %% [markdown]
# # Теория построения регрессии
# ### Вопрос 1
# Выберите предположения, выполнение которых необходимо и достаточно для того, чтобы метод наименьших квадратов давал несмещённые и состоятельные оценки истинных коэффициентов регрессии.
#  * Случайность ошибок: 𝔼(ε∣∣x)=0
#  * ~~Гомоскедастичность ошибок: 𝔻(ε∣∣x)=σ2~~
#  * ~~Нормальность ошибок: ε∣∣x∼N(0,σ2)~~
#  * Полнота ранга X: ни один из признаков не является линейной комбинацией других признаков (rankX=k+1)
#  * Линейность отклика: y=Xβ+ε
#  * Случайность выборки: наблюдения (xi,yi) независимы
#
# ### Вопрос 2
# Выберите верные утверждения о дисперсии коэффициента регрессии $\hat{β}_{j}$, получаемого методом наименьших квадратов.
#  * Чем сильнее признак $x_{j}$ варьируется в выборке, тем меньше дисперсия $\hat{β}_{j}$
#  * Чем больше $R_{j}$, коэффициент детерминации при регрессии $x_{j}$ на все остальные признаки, тем больше дисперсия $\hat{β}_{j}$
#  * Чем больше дисперсия ошибки ε, тем больше дисперсия $\hat{β}_{j}$
#  * Чем больше объём выборки n, тем меньше дисперсия $\hat{β}_{j}$
#  * ~~Чем больше $R_{j}$, коэффициент детерминации при регрессии $x_{j}$ на все остальные признаки, тем меньше дисперсия $\hat{β}_{j}$~~
#  * ~~Чем сильнее признак $x_{j}$ варьируется в выборке, тем больше дисперсия $\hat{β}_{j}$~~
#
# ### Вопрос 3
# Выберите наиболее точное определение. Мультиколлинеарность — это:
#
#  * близкая к линейной зависимость между столбцами матрицы X
#  * ~~близкая к линейной зависимость между исходными признаками x1,…,xk~~
#  * ~~линейная зависимость между столбцами матрицы X~~
#  * ~~параллельность большого количества ненулевых векторов~~
#
# ### Вопрос 4
# Перед вами 100(1−α)% доверительный интервал для σ2 —дисперсии ошибки в регрессионной модели:
#
# RSSχ2n−k−1,1−α/2≤σ2≤RSSχ2n−k−1,α/2
# Симметричен ли этот доверительный интервал относительно точечной оценки σ^2=1n−k−1RSS?
#
#  * Да, центр доверительных интервалов всегда совпадает с точечной оценкой
#  * Нет, потому что распределение хи-квадрат несимметрично
#
# ### Вопрос 5
#
# Какое из предположений регрессии проверяется с помощью критерия Бройша-Пагана?
#
# Гомоскедастичность ошибок: 𝔻(ε∣∣x)=σ2
