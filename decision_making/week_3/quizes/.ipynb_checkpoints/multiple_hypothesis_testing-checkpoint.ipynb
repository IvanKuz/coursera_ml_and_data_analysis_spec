# %% [markdown]
# # Поправки на множественную проверку
# ### Вопрос 1
# Поправка Бонферрони — это процедура:
#
#  * одношаговая — все достигаемые уровни значимости сравниваются с одним и тем же порогом
#  * ~~нисходящая — достигаемые уровни значимости перебираются от самых маленьких к самым большим~~
#  * ~~восходящая — достигаемые уровни значимости перебираются от самых больших к самым маленьким~~
#
# ### Вопрос 2
# Выберите правильное выражение для модифицированных достигаемых уровней значимости метода Холма.
# $$\tilde{p}_{(i)}=min(1,max((m−i+1)p_{(i)},\tilde{p}_{(i−1)}))$$
#
# ### Вопрос 3
# При каких условиях метод Холма контролирует групповую вероятность ошибки?
#  * ~~При условии, что статистики, проверяющие все гипотезы, независимы~~
#  * ~~Не при каких, метод Холма контролирует только ожидаемую долю ложных отклонений~~
#  * При любых
#
# ### Вопрос 4
# Какую меру числа ошибок первого рода контролирует метод Бенджамини-Хохберга?
#
# Ожидаемую долю ложных отклонений, $FDR=𝔼(\frac{V}{max(R,1)})$
#
# ### Вопрос 5
# Какой из трёх методов поправки на множественную проверку позволяет отвергнуть больше всего гипотез?
#
#  * ~~Бонферрони~~
#  * ~~Холма~~
#  * Бенджамини-Хохберга
#
# ### Вопрос 6
# У вас есть 5000 независимых выборок. На каждой из них вы проверили гипотезу о равенстве среднего нулю, а затем сделали поправку на множественность методом Бенджамини-Хохберга с α=0.05. Для 100 выборок нулевая гипотеза была отвергнута. Что можно сказать об этих ста гипотезах?
#
#  * ~~Среди этих ста гипотез не больше пяти ложно отвергнутых~~
#  * ~~Вероятность того, что хотя бы одна из ста отвергнута ложно, не превосходит 0.05~~
#  * Если мы будем повторять такой эксперимент много раз, среди отвергаемых гипотез будет в среднем 5% ложно отвергнутых
#  * ~~Строго говоря, ничего — предположения метода Бенджамини-Хохберга не выполняются, так что ничего гарантировать нельзя~~
