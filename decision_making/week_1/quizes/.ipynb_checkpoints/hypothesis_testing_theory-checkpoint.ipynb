# %% [markdown]
# # Теория проверки гипотез
# ### Вопрос 1
# Если p≤α, то H0 отвергается в пользу H1
#
# ### Вопрос 2
# Достигаемый уровень значимости — это ничего из перечисленного:
#  * вероятность справедливости нулевой гипотезы
#  * вероятность справедливости нулевой гипотезы при таком значении статистики
#  * вероятность получить такое значение статистики при справедливости нулевой гипотезы
#
# ### Вопрос 3
# Ошибка первого рода — это отвержение верной нулевой гипотезы
#
# ### Вопрос 4
# Выберите верные утверждения про пару (H0,H1).
#
#  * порядок в паре (H0,H1) выбирается так, чтобы H0 значила "ничего не происходит", а H1 — "мы сделали важное открытие", потому что с помощью проверки гипотез нельзя доказать справедливость H0: при p≤α, скорее всего, верна H1, а при p>α либо верна H0, либо данных недостаточно.
#  * ~~Вместо (H0,H1) можно взять (H1,H0), статистический критерий от этого не поменяется~~
#  * ~~Гипотезы H0 и H1 про какой-то параметр θ вместе должны покрывать всё множество возможных значений параметра~~
#  * H0 в каком-то смысле для нас важнее: мы верим в неё по умолчанию, и отказываемся от неё только если есть хорошие доказательства
#
# ### Вопрос 5
# Что такое мощность статистического критерия? Вероятность отвергнуть неверную нулевую гипотезу
#
# ### Вопрос 6
# Какое свойство статистического критерия важнее?
#  * ~~Простота вычисления достигаемого уровня значимости: нулевое распределение статистики должно задаваться аналитически~~
#  * ~~Неконсервативность: вероятность ошибки первого рода не должна быть намного меньше α~~
#  * ~~Мощность: должна быть как можно больше~~
#  * Корректность: вероятность ошибки первого рода не должна превышать α
#
# ### Вопрос 7
#
# Выберите верные утверждения про статистическую и практическую значимость.
#  * ~~Любой практически значимый результат статистически значим~~
#  * ~~Чтобы оценить практическую значимость полученного размера эффекта, не нужно никаких специальных знаний, достаточно здравого смысла~~
#  * ~~И статистическую, и практическую значимость можно вычислить по формулам~~
#  * ~~Любой статистически значимый результат практически значим~~
#  * Размер эффекта нас интересует в первую очередь, а достигаемый уровень значимости — это просто способ удостовериться, что мы его достаточно точно оценили
#  * С ростом объёма выборки эффекты всё более незначительных размеров будут признаваться статистически значимыми
